# %%
# Hypothesis Statement
# h0(Null hypothesis) = There is no difference b/n the diameter of the cutlet.
# hA(Alternate hypothesis) = The diameter of the cutlets are different. 
# Assuming α = 0.05

# %%
#IMPORTING ALL THE REQUIRED LIBRARIES
import pandas as pd
import numpy as np
from scipy import stats
import scipy

# %%
# loading the dataset
cutlet = pd.read_csv('../input/data-science-assignments/HYPOTHESIS TESTING/Cutlets.csv')

# %%
# viewing the data set
cutlet

# %%
# will display top few entries
cutlet.head()

# %%
# will display the information about the data set i.e. datatypes, no null/null values, index range
cutlet.info()

# %%
# performing the test(relevant to the data set provided - t-test) 
stats.t.ppf(0.05,33)

# %%
# p-value = -1.692 which is less than 0.05, therefore accepting the alternate hypothesis to be true.
# i.e. the diameter of the cutlets are different
